# %%
import geopandas
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
shapefile = r"E:\git\GIS5578\GIS5578-FOSS\datasets\states.shp"
df = geopandas.read_file(shapefile)

# %%
#df.keys()
df.plot()
plt.show()

# %%
df.keys()
# Out:
# Index(['STATEFP', 'STATENS', 'AFFGEOID', 'GEOID', 'STUSPS', 'NAME', 'LSAD',
#        'ALAND', 'AWATER', 'ID', 'geometry'],
#       dtype='object')

# %%
df.ix[0].geometry

# %%
df.columns

# %%
df.ix[:].geometry

# %%
dir(df['NAME'])

# %%
df.plot(column=df['NAME'], cmap='OrRd');
plt.show()

# %%
import georasters

# %%
#help(rasterstats.io.rasterio.open) 
raster = georasters.from_file(r"E:\git\GIS5578\GIS5578-FOSS\datasets\glc2000_clipped_nodata.tif")

# %%
plt.figure(figsize=(12, 8))
raster.plot()

# %%
minx, miny, maxx, maxy = raster.bounds
from shapely.geometry import box, mapping
myPoly = box(minx, miny, maxx, maxx)
myPoly.to_wkt()
#minx, miny, maxx, maxy
